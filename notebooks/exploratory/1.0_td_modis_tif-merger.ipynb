# %% [markdown]
# # Geotif Merging Code
# Job 1: Small-Scale Merge - Firstly, a small sample of the entire tif set was merged within xarray.
#
# Job 2: Full-Scale Merge - Secondly, the entire tif set was merged within xarray.
#
# N.B. The second, larger set, fails to merge when chunked and run on desktop PC.
# This may be something to do with memory limitations perhaps?

# %% [markdown]
# ### Prerequisites
# Before being able to run the below code, a suitable conda environment must be set up.
# This environment must be set up to handle the rioxarray module, and associated useful modules.
# If you already have miniconda set up on your local PC all you need to do is set up the environment from the terminal.
# The following code will be of use:
# - $ conda config --prepend channels conda-forge
# - $ conda config --set channel-priority strict
# - $ conda create -n rioxarray_env rioxarray
# - $ conda activate rioxarray_env
# - $ conda install ipykernel
# - $ conda install matplotlib

# %% [markdown]
# ## Pre-Job Import

# %%
# Required modules are imported.
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import xarray as xr
import rioxarray
import glob
import os

# %% [markdown]
# ## Job 1: Small-Scale Merge

# %%
# First of all the list of tif files are imported from local store.
geotif_list = glob.glob('/Users/thomasdodd/OneDrive - Millfield Enterprises Limited/Cambridge/AI4ER/Lent/GTC/practice_classified_files/Fire_data/Classified/*Simple.tif') 
# To assure the size of this geotif set a small print script is carried out.
print(f"Number of geotif files: {len(geotif_list)}")
# Out:
# Number of geotif files: 1024

# %%
# Create an empty array for all the opened geotif files
opened_files = []

# A for loop is set up to iterate over the geotif_list
# opening all the tifs as it goes into the opened_files
for geotif in geotif_list:
    src = xr.open_rasterio(geotif)
    # Lats and longs are named correctly within the xarray dataarray
    src = src.rename({'x': 'lon', 'y': 'lat'})
    # It is important to name the opened tif xarray dataarrays
    # so they happily merge later.
    src = src.rename('foo')
    # Files are appended to the opened_files array
    opened_files.append(src)
# Out:
# /var/folders/s5/qt7qmkzj5fjckphkfjnykflc0000gn/T/ipykernel_78936/2881797393.py:7: DeprecationWarning: open_rasterio is Deprecated in favor of rioxarray. For information about transitioning, see: https://corteva.github.io/rioxarray/stable/getting_started/getting_started.html
#   src = xr.open_rasterio(geotif)

# %%
# Assign three xarray dataarrays to three arbitrary variables.
x = opened_files[0]
y = opened_files[1]
z = opened_files[2]

# %%
# Merge the three xarray dataarrays into a single xarray dataset.
xr_partial = xr.merge([x,y,z])
xr_partial
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 2361, lon: 2429, band: 1)
# Coordinates:
#   * lat      (lat) float64 50.93 50.93 50.93 50.93 50.93 ... 52.9 52.9 52.9 52.9
#   * lon      (lon) float64 25.56 25.56 25.56 25.56 ... 29.05 29.05 29.05 29.05
#   * band     (band) int64 1
# Data variables:
#     foo      (band, lat, lon) float64 nan nan nan nan nan ... nan nan nan nan
# Attributes:
#     transform:               (0.0001796630568239043, 0.0, 28.321545288549803,...
#     crs:                     +init=epsg:4326
#     res:                     (0.0001796630568239043, 0.0001796630568239043)
#     is_tiled:                1
#     nodatavals:              (0.0,)
#     scales:                  (1.0,)
#     offsets:                 (0.0,)
#     AREA_OR_POINT:           Area
#     TIFFTAG_RESOLUTIONUNIT:  1 (unitless)
#     TIFFTAG_XRESOLUTION:     1
#     TIFFTAG_YRESOLUTION:     1

# %% [markdown]
# ## Job 2: Full-Scale Merge

# %%
# Full scale merge currently fails because it overcomes the amount of memory actually available to take on the problem.
xr_entire = xr.merge(opened_files)
xr_entire
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [6], in <module>
# ----> 1 xr_entire = xr.merge(opened_files)
#       2 xr_entire
#
# File ~/opt/anaconda3/envs/rioxarray_env/lib/python3.10/site-packages/xarray/core/merge.py:905, in merge(objects, compat, join, fill_value, combine_attrs)
#     902     obj = obj.to_dataset(promote_attrs=True) if isinstance(obj, DataArray) else obj
#     903     dict_like_objects.append(obj)
# --> 905 merge_result = merge_core(
#     906     dict_like_objects,
#     907     compat,
#     908     join,
#     909     combine_attrs=combine_attrs,
#     910     fill_value=fill_value,
#     911 )
#     912 return Dataset._construct_direct(**merge_result._asdict())
#
# File ~/opt/anaconda3/envs/rioxarray_env/lib/python3.10/site-packages/xarray/core/merge.py:634, in merge_core(objects, compat, join, combine_attrs, priority_arg, explicit_coords, indexes, fill_value)
#     631 _assert_compat_valid(compat)
#     633 coerced = coerce_pandas_values(objects)
# --> 634 aligned = deep_align(
#     635     coerced, join=join, copy=False, indexes=indexes, fill_value=fill_value
#     636 )
#     637 collected = collect_variables_and_indexes(aligned)
#     639 prioritized = _get_priority_vars_and_indexes(aligned, priority_arg, compat=compat)
#
# File ~/opt/anaconda3/envs/rioxarray_env/lib/python3.10/site-packages/xarray/core/alignment.py:435, in deep_align(objects, join, copy, indexes, exclude, raise_on_invalid, fill_value)
#     432     else:
#     433         out.append(variables)
# --> 435 aligned = align(
#     436     *targets,
#     437     join=join,
#     438     copy=copy,
#     439     indexes=indexes,
#     440     exclude=exclude,
#     441     fill_value=fill_value,
#     442 )
#     444 for position, key, aligned_obj in zip(positions, keys, aligned):
#     445     if key is no_key:
#
# File ~/opt/anaconda3/envs/rioxarray_env/lib/python3.10/site-packages/xarray/core/alignment.py:367, in align(join, copy, indexes, exclude, fill_value, *objects)
#     365     new_obj = obj.copy(deep=copy)
#     366 else:
# --> 367     new_obj = obj.reindex(
#     368         copy=copy, fill_value=fill_value, indexers=valid_indexers
#     369     )
#     370 new_obj.encoding = obj.encoding
#     371 result.append(new_obj)
#
# File ~/opt/anaconda3/envs/rioxarray_env/lib/python3.10/site-packages/xarray/core/dataset.py:2943, in Dataset.reindex(self, indexers, method, tolerance, copy, fill_value, **indexers_kwargs)
#    2743 def reindex(
#    2744     self,
#    2745     indexers: Mapping[Any, Any] = None,
#    (...)
#    2750     **indexers_kwargs: Any,
#    2751 ) -> "Dataset":
#    2752     """Conform this object onto a new set of indexes, filling in
#    2753     missing values with ``fill_value``. The default fill value is NaN.
#    2754
#    (...)
#    2941
#    2942     """
# -> 2943     return self._reindex(
#    2944         indexers,
#    2945         method,
#    2946         tolerance,
#    2947         copy,
#    2948         fill_value,
#    2949         sparse=False,
#    2950         **indexers_kwargs,
#    2951     )
#
# File ~/opt/anaconda3/envs/rioxarray_env/lib/python3.10/site-packages/xarray/core/dataset.py:2972, in Dataset._reindex(self, indexers, method, tolerance, copy, fill_value, sparse, **indexers_kwargs)
#    2969 if bad_dims:
#    2970     raise ValueError(f"invalid reindex dimensions: {bad_dims}")
# -> 2972 variables, indexes = alignment.reindex_variables(
#    2973     self.variables,
#    2974     self.sizes,
#    2975     self.xindexes,
#    2976     indexers,
#    2977     method,
#    2978     tolerance,
#    2979     copy=copy,
#    2980     fill_value=fill_value,
#    2981     sparse=sparse,
#    2982 )
#    2983 coord_names = set(self._coord_names)
#    2984 coord_names.update(indexers)
#
# File ~/opt/anaconda3/envs/rioxarray_env/lib/python3.10/site-packages/xarray/core/alignment.py:634, in reindex_variables(variables, sizes, indexes, indexers, method, tolerance, copy, fill_value, sparse)
#     631 needs_masking = any(d in masked_dims for d in var.dims)
#     633 if needs_masking:
# --> 634     new_var = var._getitem_with_mask(key, fill_value=fill_value_)
#     635 elif all(is_full_slice(k) for k in key):
#     636     # no reindexing necessary
#     637     # here we need to manually deal with copying data, since
#     638     # we neither created a new ndarray nor used fancy indexing
#     639     new_var = var.copy(deep=copy)
#
# File ~/opt/anaconda3/envs/rioxarray_env/lib/python3.10/site-packages/xarray/core/variable.py:824, in Variable._getitem_with_mask(self, key, fill_value)
#     820     mask = indexing.create_mask(indexer, self.shape, data)
#     821     # we need to invert the mask in order to pass data first. This helps
#     822     # pint to choose the correct unit
#     823     # TODO: revert after https://github.com/hgrecco/pint/issues/1019 is fixed
# --> 824     data = duck_array_ops.where(np.logical_not(mask), data, fill_value)
#     825 else:
#     826     # array cannot be indexed along dimensions of size 0, so just
#     827     # build the mask directly instead.
#     828     mask = indexing.create_mask(indexer, self.shape)
#
# File ~/opt/anaconda3/envs/rioxarray_env/lib/python3.10/site-packages/xarray/core/duck_array_ops.py:285, in where(condition, x, y)
#     283 def where(condition, x, y):
#     284     """Three argument where() with better dtype promotion rules."""
# --> 285     return _where(condition, *as_shared_dtype([x, y]))
#
# File <__array_function__ internals>:180, in where(*args, **kwargs)
#
# KeyboardInterrupt:
